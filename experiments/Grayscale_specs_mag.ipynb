# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from zipfile import ZipFile
file_name = "/content/drive/My Drive/calls_grayscaless.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print(file_name)
# Out:
# /content/drive/My Drive/calls_grayscaless.zip

# %%
# !unzip "/content/drive/My Drive/calls_grayscaless.zip"
# Out:
# Archive:  /content/drive/My Drive/calls_grayscaless.zip
#    creating: content/plot_calls/
#   inflating: content/plot_calls/round3_callscalls204.png
#   inflating: content/plot_calls/rnd2_clcalls168.png
#   inflating: content/plot_calls/round3_callscalls410.png
#   inflating: content/plot_calls/round3_callscalls414.png
#   inflating: content/plot_calls/round3_callscalls168.png
#   inflating: content/plot_calls/round3_callscalls106.png
#   inflating: content/plot_calls/round3_callscalls275.png
#   inflating: content/plot_calls/rnd2_clcalls112.png
#   inflating: content/plot_calls/round3_callscalls167.png
#   inflating: content/plot_calls/rnd2_clcalls206.png
#   inflating: content/plot_calls/rnd2_clcalls342.png
#   inflating: content/plot_calls/round3_callscalls372.png
#   inflating: content/plot_calls/round3_callscalls256.png
#   inflating: content/plot_calls/round3_callscalls217.png
#   inflating: content/plot_calls/round3_callscalls371.png
# ...

# %%
from zipfile import ZipFile
file_name = "/content/drive/My Drive/no_calls_grayscaless.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print(file_name)
# Out:
# /content/drive/My Drive/no_calls_grayscaless.zip

# %%
# !unzip "/content/drive/My Drive/no_calls_grayscaless.zip"
# Out:
# Archive:  /content/drive/My Drive/no_calls_grayscaless.zip
#    creating: content/negtive_old/
#   inflating: content/negtive_old/ro33cacalls48.wav
#   inflating: content/negtive_old/ro33cacalls159.wav
#   inflating: content/negtive_old/ro33cacalls137.wav
#   inflating: content/negtive_old/ro33cacalls141.wav
#   inflating: content/negtive_old/rc2calcalls311.wav
#   inflating: content/negtive_old/rc2calcalls74.wav
#   inflating: content/negtive_old/ro33cacalls74.wav
#   inflating: content/negtive_old/ro33cacalls295.wav
#   inflating: content/negtive_old/rc2calcalls180.wav
#   inflating: content/negtive_old/ro33cacalls196.wav
#   inflating: content/negtive_old/ro33cacalls419.wav
#   inflating: content/negtive_old/ro33cacalls219.wav
#   inflating: content/negtive_old/ro33cacalls414.wav
#   inflating: content/negtive_old/rc2calcalls72.wav
#   inflating: content/negtive_old/ro33cacalls345.wav
#   inflating: content/negtive_old/rc2calcalls352.wav
# ...

# %%
import os
nb_train_samples = sum(len(files) for _, _, files in os.walk("/content/content/negtive_old"))
print(nb_train_samples)
# Out:
# 786

# %%
import os

# %%
# Please replace this with YOUR path to orcadata
basePath = r"/content/content/negtive_old/"
plotPath = "/content/no_calls_plot/"
onlyfiles = [f for f in listdir(basePath) if isfile(join(join(basePath, f)))]

for idx, file in enumerate(onlyfiles):
    data, samplerate = sf.read(join(basePath, file))
    f, t, spec = signal.spectrogram(data, samplerate)
    filename = file.split(sep=".")[0]
    i=0
    i=i+1    
    fig, ax = plt.subplots(1, 1)
    ax.specgram(data, Fs=samplerate,cmap="gray", NFFT=1024)
    
    # Rescale y axis labels from Hz to KHz
    scale_y = 1000
    ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
    ax.yaxis.set_major_formatter(ticks_y)

    fig.set_size_inches(10, 10)
    ax.set_axis_off()

    plt.savefig(join(plotPath, 
                 filename + ".png"),
      
        dpi=80,
        bbox_inches="tight",
        quality=95,
        pad_inches=0.0)
    plt.close(fig)

# %%
import soundfile as sf
import numpy as np
from os import listdir
from os.path import isfile, join
from scipy import signal
import soundfile as sf
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
# !pip install soundfile

# %%
from zipfile import ZipFile
file_name = "/content/drive/My Drive/no_calls_test_graysddcale.zip"

with ZipFile(file_name, 'r') as zip:
  zip.extractall()
  print(file_name)
# Out:
# /content/drive/My Drive/no_calls_test_graysddcale.zip

# %%
# !unzip "/content/drive/My Drive/no_calls_test_graysddcale.zip"
# Out:
# Archive:  /content/drive/My Drive/no_calls_test_graysddcale.zip
#    creating: content/test/
#    creating: content/test/.ipynb_checkpoints/
#    creating: content/test/test_calls/
#   inflating: content/test/test_calls/testcalls52.png
#   inflating: content/test/test_calls/testcalls7.png
#   inflating: content/test/test_calls/testcalls21.png
#   inflating: content/test/test_calls/testcalls79.png
#   inflating: content/test/test_calls/testcalls42.png
#   inflating: content/test/test_calls/testcalls46.png
#   inflating: content/test/test_calls/testcalls39.png
#   inflating: content/test/test_calls/testcalls3.png
#   inflating: content/test/test_calls/testcalls37.png
#   inflating: content/test/test_calls/testcalls33.png
#   inflating: content/test/test_calls/testcalls96.png
#   inflating: content/test/test_calls/testcalls49.png
#   inflating: content/test/test_calls/testcalls31.png
#   inflating: content/test/test_calls/testcalls87.png
# ...

# %%
import cv2
d=cv2.imread("/content/content/test/no_calls/test_negcalls10.png")
d.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-4364680736bd> in <module>()
#       1 import cv2
#       2 d=cv2.imread("/content/content/test/no_calls/test_negcalls10.png")
# ----> 3 d.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
import glob

# %%
filelist=os.listdir('/content/training/calls/')
for fichier in filelist[:]: # filelist[:] makes a copy of filelist.
    if not(fichier.endswith(".png")):
        filelist.remove(fichier)
print(filelist)
# Out:
# ['rnd2_clcalls81.png', 'rnd2_clcalls187.png', 'rnd2_clcalls241.png', 'rnd2_clcalls151.png', 'rnd2_clcalls319.png', 'round3_callscalls56.png', 'rnd2_clcalls74.png', 'rnd2_clcalls281.png', 'rnd2_clcalls24.png', 'round3_callscalls141.png', 'rnd2_clcalls201.png', 'round3_callscalls349.png', 'round3_callscalls330.png', 'round3_callscalls229.png', 'rnd2_clcalls77.png', 'rnd2_clcalls42.png', 'round3_callscalls16.png', 'round3_callscalls19.png', 'rnd2_clcalls128.png', 'rnd2_clcalls249.png', 'round3_callscalls55.png', 'round3_callscalls17.png', 'round3_callscalls216.png', 'round3_callscalls95.png', 'round3_callscalls361.png', 'round3_callscalls64.png', 'rnd2_clcalls279.png', 'round3_callscalls140.png', 'rnd2_clcalls230.png', 'round3_callscalls72.png', 'round3_callscalls15.png', 'round3_callscalls58.png', 'round3_callscalls77.png', 'rnd2_clcalls234.png', 'rnd2_clcalls19.png', 'round3_callscalls373.png', 'round3_callscalls23.png', 'round3_callscalls103.png', 'round3_callscalls179.png', 'rnd2_cl
# ...

# %%
filelist=os.listdir('/content/training/no_calls/')
for fichier in filelist[:]: # filelist[:] makes a copy of filelist.
    if not(fichier.endswith(".png")):
        filelist.remove(fichier)
print(filelist)
# Out:
# ['ro33cacalls301.png', 'ro33cacalls157.png', 'ro33cacalls326.png', 'rc2calcalls82.png', 'ro33cacalls47.png', 'rc2calcalls53.png', 'ro33cacalls159.png', 'rc2calcalls195.png', 'ro33cacalls82.png', 'rc2calcalls70.png', 'rc2calcalls25.png', 'ro33cacalls229.png', 'ro33cacalls173.png', 'rc2calcalls39.png', 'ro33cacalls160.png', 'rc2calcalls355.png', 'ro33cacalls131.png', 'rc2calcalls68.png', 'rc2calcalls72.png', 'ro33cacalls28.png', 'rc2calcalls268.png', 'ro33cacalls114.png', 'ro33cacalls296.png', 'ro33cacalls70.png', 'rc2calcalls90.png', 'ro33cacalls182.png', 'rc2calcalls11.png', 'ro33cacalls136.png', 'rc2calcalls241.png', 'ro33cacalls275.png', 'ro33cacalls270.png', 'rc2calcalls57.png', 'ro33cacalls30.png', 'rc2calcalls175.png', 'ro33cacalls13.png', 'ro33cacalls300.png', 'ro33cacalls109.png', 'ro33cacalls197.png', 'ro33cacalls86.png', 'ro33cacalls154.png', 'ro33cacalls372.png', 'rc2calcalls290.png', 'rc2calcalls304.png', 'ro33cacalls84.png', 'ro33cacalls244.png', 'rc2calcalls209.png', 'ro
# ...

# %%
filelist=os.listdir('/content/content/test/calls/')
for fichier in filelist[:]: # filelist[:] makes a copy of filelist.
    if not(fichier.endswith(".png")):
        filelist.remove(fichier)
print(filelist)
# Out:
# ['testcalls51.png', 'testcalls95.png', 'testcalls72.png', 'testcalls14.png', 'testcalls64.png', 'testcalls86.png', 'testcalls4.png', 'testcalls8.png', 'testcalls67.png', 'testcalls66.png', 'testcalls31.png', 'testcalls85.png', 'testcalls89.png', 'testcalls34.png', 'testcalls70.png', 'testcalls62.png', 'testcalls59.png', 'testcalls5.png', 'testcalls101.png', 'testcalls46.png', 'testcalls69.png', 'testcalls17.png', 'testcalls52.png', 'testcalls97.png', 'testcalls50.png', 'testcalls33.png', 'testcalls25.png', 'testcalls22.png', 'testcalls68.png', 'testcalls39.png', 'testcalls35.png', 'testcalls61.png', 'testcalls3.png', 'testcalls80.png', 'testcalls60.png', 'testcalls38.png', 'testcalls47.png', 'testcalls57.png', 'testcalls20.png', 'testcalls83.png', 'testcalls29.png', 'testcalls42.png', 'testcalls32.png', 'testcalls90.png', 'testcalls6.png', 'testcalls37.png', 'testcalls9.png', 'testcalls13.png', 'testcalls24.png', 'testcalls26.png', 'testcalls76.png', 'testcalls45.png', 'testcalls56.p
# ...

# %%
filelist=os.listdir('/content/content/test/no_calls/')
for fichier in filelist[:]: # filelist[:] makes a copy of filelist.
    if not(fichier.endswith(".png")):
        filelist.remove(fichier)
print(filelist)
# Out:
# ['test_negcalls76.png', 'test_negcalls99.png', 'test_negcalls81.png', 'test_negcalls63.png', 'test_negcalls4.png', 'test_negcalls47.png', 'test_negcalls84.png', 'test_negcalls42.png', 'test_negcalls70.png', 'test_negcalls74.png', 'test_negcalls12.png', 'test_negcalls30.png', 'test_negcalls22.png', 'test_negcalls100.png', 'test_negcalls57.png', 'test_negcalls5.png', 'test_negcalls38.png', 'test_negcalls37.png', 'test_negcalls73.png', 'test_negcalls62.png', 'test_negcalls7.png', 'test_negcalls64.png', 'test_negcalls101.png', 'test_negcalls96.png', 'test_negcalls93.png', 'test_negcalls90.png', 'test_negcalls98.png', 'test_negcalls8.png', 'test_negcalls13.png', 'test_negcalls51.png', 'test_negcalls32.png', 'test_negcalls31.png', 'test_negcalls23.png', 'test_negcalls25.png', 'test_negcalls89.png', 'test_negcalls72.png', 'test_negcalls50.png', 'test_negcalls82.png', 'test_negcalls1.png', 'test_negcalls6.png', 'test_negcalls61.png', 'test_negcalls19.png', 'test_negcalls87.png', 'test_negcal
# ...

# %%
for files in "/content/training/calls/":
    print(glob.glob('images/*.png'))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
import os

train_data_path = '/content/training/'
test_data_path = '/content/content/test/'

#Parametres
img_width, img_height = 604, 620

nb_train_samples = sum(len(files) for _, _, files in os.walk(train_data_path))
print(nb_train_samples)
epochs = 250
batch_size = 41
# Out:
# 1572

# %%
import matplotlib
matplotlib.use("Agg")



from keras.preprocessing.image import ImageDataGenerator
from keras.applications import VGG16
from keras.applications import ResNet152V2
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.optimizers import Adam
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
from keras import models
from keras import layers
from keras import optimizers
from keras.applications import VGG16
from keras.applications import InceptionResNetV2
import sys, numpy
import os
from keras import optimizers, regularizers
from keras.layers import Dropout, Flatten, Dense, Activation, Input
from keras import callbacks, regularizers
from keras.models import load_model
import matplotlib.pyplot as plt 
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.engine import  Model
from keras.layers import Conv2D, GlobalAveragePooling2D
from sklearn import metrics
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from keras import models
from keras import layers
from keras import optimizers
from keras.applications import VGG16
from keras.applications import InceptionResNetV2
import sys, numpy
import os
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers, regularizers
from keras.models import Sequential
from keras.models import load_model
import matplotlib.pyplot as plt 
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.engine import  Model
from keras.layers import Conv2D, GlobalAveragePooling2D
from sklearn import metrics
import itertools
import tensorflow as tf

from google.colab import files
import datetime, os
# %matplotlib inline

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)


model = Sequential()
model.add(Conv2D(64, (5, 5), padding = 'same', strides=3, input_shape=input_shape))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Conv2D(64, (5, 5), strides=3, padding = 'same'))
model.add(Activation('relu'))

model.add(Conv2D(128, (5, 5), strides=3, padding = 'same'))
model.add(Activation('relu'))
model.add(Dropout(0.6))

model.add(Conv2D(128, (5, 5), strides=3, padding = 'same'))
model.add(Activation('relu'))
model.add(Dropout(0.6))


model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=3e-5),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_17 (Conv2D)           (None, 202, 207, 64)      4864
# _________________________________________________________________
# activation_25 (Activation)   (None, 202, 207, 64)      0
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 202, 207, 64)      0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 68, 69, 64)        102464
# _________________________________________________________________
# activation_26 (Activation)   (None, 68, 69, 64)        0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 23, 23, 128)       204928
# _________________________________________________________________
# activation_27 (Activation)   (None, 23, 23, 128)       0
# ...

# %%
train_generator.image_shape=(604,620,1)

# %%
train_generator.image_shape
# Out:
# (604, 620, 1)

# %%
train_datagen = ImageDataGenerator(rescale=1. / 255)
test_datagen = ImageDataGenerator(rescale=1. / 255)
train_batchsize = 41

train_generator = train_datagen.flow_from_directory(
    train_data_path,
    target_size=(img_width, img_height),
    batch_size=train_batchsize,
    class_mode='binary',
shuffle=True)


logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)
history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,

    epochs=180,
    )

model.save('srkw_v2.2.h5')
# Out:
# Found 1572 images belonging to 3 classes.
# Epoch 1/180
# 38/38 [==============================] - 23s 611ms/step - loss: -11.0104 - accuracy: 0.4918
# Epoch 2/180
# 38/38 [==============================] - 23s 604ms/step - loss: -818.4416 - accuracy: 0.5062
# Epoch 3/180
# 38/38 [==============================] - 23s 607ms/step - loss: -19370.5306 - accuracy: 0.4925
# Epoch 4/180
# 38/38 [==============================] - 23s 606ms/step - loss: -188276.4686 - accuracy: 0.5016
# Epoch 5/180
# 38/38 [==============================] - 23s 610ms/step - loss: -1111902.7257 - accuracy: 0.4879
# Epoch 6/180
# 38/38 [==============================] - 23s 607ms/step - loss: -4246365.3718 - accuracy: 0.5127
# Epoch 7/180
# 38/38 [==============================] - 23s 602ms/step - loss: -12931330.9531 - accuracy: 0.5069
# Epoch 8/180
# 38/38 [==============================] - 23s 616ms/step - loss: -34988950.1053 - accuracy: 0.4942
# Epoch 9/180
# ...

# %%
# !zip "grayscale_zip_train.zip" "/content/Model_Training/"
# Out:
# updating: content/Model_Training/ (stored 0%)
