# %%
data, samplerate = sf.read("/content/callstest_rnd2_clcalls39.wav")
f, t, spec = signal.spectrogram(data, samplerate)

fig, ax = plt.subplots(1, 1)
ax.specgram(data, Fs=samplerate,cmap="gray", NFFT=1024)
    
scale_y = 1000
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)

ax.set_axis_off()

plt.savefig( "color.png")

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from scipy import signal
import soundfile as sf

# %%
# !pip install soundfile

# %%
data, samplerate = sf.read("/content/callstest_rnd2_clcalls39.wav")
f, t, spec = signal.spectrogram(data, samplerate)

fig, ax = plt.subplots(1, 1)
ax.specgram(data, Fs=samplerate, NFFT=1024)
    
scale_y = 1000
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)

ax.set_axis_off()

plt.savefig( "color.png")

# %%
data, samplerate = sf.read("/content/callstest_rnd2_clcalls5.wav")
f, t, spec = signal.spectrogram(data, samplerate)

fig, ax = plt.subplots(1, 1)
ax.specgram(data, Fs=samplerate, NFFT=1024)
    
scale_y = 1000
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)

ax.set_axis_off()

plt.savefig( "color.png")

# %%
data, samplerate = sf.read("/content/callstest_rnd2_clcalls50.wav")
f, t, spec = signal.spectrogram(data, samplerate)

fig, ax = plt.subplots(1, 1)
ax.specgram(data, Fs=samplerate, NFFT=1024)
    
scale_y = 1000
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)

ax.set_axis_off()

plt.savefig( "color.png")

# %%
data, samplerate = sf.read("/content/callstest_rnd2_clcalls50.wav")
f, t, spec = signal.spectrogram(data, samplerate)

fig, ax = plt.subplots(1, 1)
ax.specgram(data, Fs=samplerate,cmap="gray" ,NFFT=1024)
    
scale_y = 1000
ticks_y = ticker.FuncFormatter(lambda x, pos: '{0:g}'.format(x/scale_y))
ax.yaxis.set_major_formatter(ticks_y)

ax.set_axis_off()

plt.savefig( "color.png")

# %%
spectrogram_data = librosa.feature.melspectrogram(data,sr=samplerate, power=1)
fig, ax = plt.subplots()
i = 0
ax.imshow(spectrogram_data)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
fig.set_size_inches(10, 10)

# %%
pcen_spectrogram = librosa.core.pcen(spectrogram_data)
fig, ax = plt.subplots()
i = 0
ax.imshow(pcen_spectrogram)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
fig.set_size_inches(10, 10)

# %%
from skimage.restoration import denoise_wavelet
im_bayes = denoise_wavelet(
        pcen_spectrogram,
        multichannel=False,
        convert2ycbcr=False,
        method="BayesShrink",
        mode="soft"
    )
pcen_spectrogram = librosa.core.pcen(im_bayes)
fig, ax = plt.subplots()
i = 0
ax.imshow(im_bayes)
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)
fig.set_size_inches(10, 10)                                                          
plt.savefig( "mellor.png")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   import sys

# %%
from PIL import Image
img = Image.open("/content/mellor.png").convert('L')
img.save('greyscale.png')
