# %% [markdown]
# ### Importing necessary packages

# %%
from keras import models
from keras import layers
from keras import optimizers
from keras.applications import VGG16
from keras.applications import InceptionResNetV2
import sys 
import numpy
import os
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers, regularizers
from keras.models import Sequential
from keras.layers import Dropout, Flatten, Dense, Activation, Input
from keras import callbacks, regularizers
from keras.models import load_model
import matplotlib.pyplot as plt 
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.engine import  Model
from keras.layers import Conv2D, GlobalAveragePooling2D
from sklearn import metrics
import matplotlib
matplotlib.use("Agg")
import keras
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.core import Dropout
from keras.layers.core import Flatten
from keras.layers.core import Dense
from keras.layers import Input
from keras.models import Model
from keras.optimizers import SGD
from keras.optimizers import Adam
from sklearn.metrics import classification_report
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import pickle
import os
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from sklearn.metrics import classification_report
import cv2

# %% [markdown]
# ### Unzipping these magnitude spectrograms that were plotted in the preprocessing of the spectrograms

# %%
# !unzip "/content/No_plot_MAG2.zip"
# Out:
# Archive:  /content/No_plot_MAG2.zip
#    creating: content/no_calls_plot2/
#   inflating: content/no_calls_plot2/rc2calcalls164.png
#   inflating: content/no_calls_plot2/rc2calcalls92.png
#   inflating: content/no_calls_plot2/rc2calcalls99.png
#   inflating: content/no_calls_plot2/rc2calcalls224.png
#   inflating: content/no_calls_plot2/rc2calcalls56.png
#   inflating: content/no_calls_plot2/rc2calcalls216.png
#   inflating: content/no_calls_plot2/ro33cacalls57.png
#   inflating: content/no_calls_plot2/ro33cacalls115.png
#   inflating: content/no_calls_plot2/ro33cacalls188.png
#   inflating: content/no_calls_plot2/ro33cacalls248.png
#   inflating: content/no_calls_plot2/ro33cacalls411.png
#   inflating: content/no_calls_plot2/rc2calcalls155.png
#   inflating: content/no_calls_plot2/rc2calcalls187.png
#   inflating: content/no_calls_plot2/ro33cacalls349.png
#   inflating: content/no_calls_plot2/ro33cacalls305.png
#   inflating: content/no_calls_plot2/ro33cacalls243.png
# ...

# %%
# !unzip "/content/calls_MAG_SAME_grayscaless.zip"
# Out:
# Archive:  /content/calls_MAG_SAME_grayscaless.zip
#    creating: content/plot_calls/
#   inflating: content/plot_calls/round3_callscalls227.png
#   inflating: content/plot_calls/rnd2_clcalls218.png
#   inflating: content/plot_calls/rnd2_clcalls264.png
#   inflating: content/plot_calls/rnd2_clcalls335.png
#   inflating: content/plot_calls/round3_callscalls42.png
#   inflating: content/plot_calls/round3_callscalls136.png
#   inflating: content/plot_calls/round3_callscalls325.png
#   inflating: content/plot_calls/round3_callscalls262.png
#   inflating: content/plot_calls/rnd2_clcalls103.png
#   inflating: content/plot_calls/round3_callscalls164.png
#   inflating: content/plot_calls/round3_callscalls357.png
#   inflating: content/plot_calls/rnd2_clcalls73.png
#   inflating: content/plot_calls/round3_callscalls48.png
#   inflating: content/plot_calls/rnd2_clcalls137.png
#   inflating: content/plot_calls/round3_callscalls134.png
#   inflating: content/plot_calls/rnd2_clcalls156.png
# ...

# %%
# !unzip "/content/test_SAME_MAG.zip"
# Out:
# Archive:  /content/test_SAME_MAG.zip
#    creating: content/test/
#    creating: content/test/.ipynb_checkpoints/
#    creating: content/test/test_calls/
#   inflating: content/test/test_calls/testcalls32.png
#   inflating: content/test/test_calls/testcalls39.png
#   inflating: content/test/test_calls/testcalls79.png
#   inflating: content/test/test_calls/testcalls93.png
#   inflating: content/test/test_calls/testcalls64.png
#   inflating: content/test/test_calls/testcalls33.png
#   inflating: content/test/test_calls/testcalls57.png
#   inflating: content/test/test_calls/testcalls15.png
#   inflating: content/test/test_calls/testcalls42.png
#   inflating: content/test/test_calls/testcalls61.png
#   inflating: content/test/test_calls/testcalls62.png
#   inflating: content/test/test_calls/testcalls87.png
#   inflating: content/test/test_calls/testcalls101.png
#   inflating: content/test/test_calls/testcalls81.png
#   inflating: content/test/test_calls/testcalls53.png
# ...

# %% [markdown]
# ### Check the shape of the image

# %%
k=cv2.imread("/content/content/test/calls/testcalls1.png")
k.shape
# Out:
# (288, 432, 3)

# %% [markdown]
# ### Enter the training and testing data path as well the batch-size and the number of epochs

# %%
train_data_path ="/content/tr2"
test_data_path = '/content/testa'
img_width, img_height = 288, 432
nb_test_samples = sum(len(files) for _, _, files in os.walk(test_data_path))
epochs = 100
batch_size = 157
print("Test samples are", +nb_test_samples)
nb_train_samples = sum(len(files) for _, _, files in os.walk(train_data_path))
print("Train samples are",+nb_train_samples)
# Out:
# Test samples are 202
# Train samples are 1572

# %% [markdown]
# ### Model Building Stage

# %%
if K.image_data_format() == 'channels_first':
    input_shape = (1, img_width, img_height)
else:
    input_shape = (img_width, img_height, 1)


model = Sequential()
model.add(Conv2D(64, (5, 5), padding = 'same', strides=3, input_shape=input_shape))
model.add(Activation('relu'))
model.add(Conv2D(64, (5, 5), strides=3, padding = 'same'))
model.add(Activation('relu'))

model.add(Conv2D(128, (5, 5),  strides=3, padding = 'same'))
model.add(Activation('relu'))

model.add(Conv2D(128, (5, 5), strides=3, padding = 'same'))
model.add(Activation('relu'))
model.add(Dropout(0.6))

model.add(Flatten())
model.add(Dense(256))
model.add(Activation('relu'))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer=optimizers.Adam(lr=3e-5),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_44 (Conv2D)           (None, 96, 144, 64)       1664
# _________________________________________________________________
# activation_54 (Activation)   (None, 96, 144, 64)       0
# _________________________________________________________________
# conv2d_45 (Conv2D)           (None, 32, 48, 64)        102464
# _________________________________________________________________
# activation_55 (Activation)   (None, 32, 48, 64)        0
# _________________________________________________________________
# conv2d_46 (Conv2D)           (None, 11, 16, 128)       204928
# _________________________________________________________________
# activation_56 (Activation)   (None, 11, 16, 128)       0
# _________________________________________________________________
# conv2d_47 (Conv2D)           (None, 4, 6, 128)         409728
# ...

# %% [markdown]
# ### Start with the training of the model

# %%
train_datagen = ImageDataGenerator(rescale=1. / 255)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_batchsize = 157

train_generator = train_datagen.flow_from_directory(
    train_data_path,
    target_size=(img_width, img_height),
    batch_size=train_batchsize,
    class_mode='binary',
    color_mode="grayscale",
shuffle=True)


history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples//train_batchsize, 
    epochs=epochs
    
    )
model.save('preprocess_mag_scipy_Srkws.h5')
# Out:
# Found 1572 images belonging to 2 classes.
# Epoch 1/100
# 10/10 [==============================] - 6s 617ms/step - loss: 0.6908 - accuracy: 0.5060
# Epoch 2/100
# 10/10 [==============================] - 6s 594ms/step - loss: 0.6940 - accuracy: 0.5095
# Epoch 3/100
# 10/10 [==============================] - 6s 591ms/step - loss: 0.6942 - accuracy: 0.5237
# Epoch 4/100
# 10/10 [==============================] - 6s 592ms/step - loss: 0.6909 - accuracy: 0.5081
# Epoch 5/100
# 10/10 [==============================] - 7s 654ms/step - loss: 0.6920 - accuracy: 0.5236
# Epoch 6/100
# 10/10 [==============================] - 5s 534ms/step - loss: 0.6898 - accuracy: 0.5183
# Epoch 7/100
# 10/10 [==============================] - 7s 671ms/step - loss: 0.6926 - accuracy: 0.5051
# Epoch 8/100
# 10/10 [==============================] - 6s 592ms/step - loss: 0.6925 - accuracy: 0.5117
# Epoch 9/100
# 10/10 [==============================] - 6s 595ms/step - loss: 0.6925 - accuracy: 0.5194
# ...

# %% [markdown]
# ### Train more....

# %%
train_datagen = ImageDataGenerator(rescale=1. / 255)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_batchsize = 157

train_generator = train_datagen.flow_from_directory(
    train_data_path,
    target_size=(img_width, img_height),
    batch_size=train_batchsize,
    class_mode='binary',
    color_mode="grayscale",
shuffle=True)


history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples//train_batchsize, 
    epochs=450
    
    )
model.save('preprocess_mag_scipy_Srkws.h5')
# Out:
# Found 1572 images belonging to 2 classes.
# Epoch 1/450
# 10/10 [==============================] - 6s 613ms/step - loss: 0.6746 - accuracy: 0.5901
# Epoch 2/450
# 10/10 [==============================] - 6s 605ms/step - loss: 0.6872 - accuracy: 0.5668
# Epoch 3/450
# 10/10 [==============================] - 6s 605ms/step - loss: 0.6735 - accuracy: 0.5731
# Epoch 4/450
# 10/10 [==============================] - 7s 675ms/step - loss: 0.6808 - accuracy: 0.5541
# Epoch 5/450
# 10/10 [==============================] - 5s 546ms/step - loss: 0.6663 - accuracy: 0.5794
# Epoch 6/450
# 10/10 [==============================] - 6s 609ms/step - loss: 0.6814 - accuracy: 0.5640
# Epoch 7/450
# 10/10 [==============================] - 6s 602ms/step - loss: 0.6807 - accuracy: 0.5590
# Epoch 8/450
# 10/10 [==============================] - 6s 607ms/step - loss: 0.6813 - accuracy: 0.5463
# Epoch 9/450
# 10/10 [==============================] - 6s 604ms/step - loss: 0.6858 - accuracy: 0.5689
# ...

# %% [markdown]
# ### ....and a little bit more until the accuracy no longer changes

# %%
train_datagen = ImageDataGenerator(rescale=1. / 255)

test_datagen = ImageDataGenerator(rescale=1. / 255)

train_batchsize = 157

train_generator = train_datagen.flow_from_directory(
    train_data_path,
    target_size=(img_width, img_height),
    batch_size=train_batchsize,
    class_mode='binary',
    color_mode="grayscale",
shuffle=True)


history = model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples//train_batchsize, 
    epochs=250
    
    )
model.save('preprocess_mag_scipy_Srkws.h5')
# Out:
# Found 1572 images belonging to 2 classes.
# Epoch 1/250
# 10/10 [==============================] - 6s 625ms/step - loss: 0.5446 - accuracy: 0.7329
# Epoch 2/250
# 10/10 [==============================] - 6s 610ms/step - loss: 0.5415 - accuracy: 0.7293
# Epoch 3/250
# 10/10 [==============================] - 6s 611ms/step - loss: 0.5359 - accuracy: 0.7322
# Epoch 4/250
# 10/10 [==============================] - 6s 609ms/step - loss: 0.5415 - accuracy: 0.7138
# Epoch 5/250
# 10/10 [==============================] - 6s 612ms/step - loss: 0.5209 - accuracy: 0.7201
# Epoch 6/250
# 10/10 [==============================] - 7s 671ms/step - loss: 0.5469 - accuracy: 0.7338
# Epoch 7/250
# 10/10 [==============================] - 6s 618ms/step - loss: 0.5602 - accuracy: 0.7279
# Epoch 8/250
# 10/10 [==============================] - 5s 541ms/step - loss: 0.5463 - accuracy: 0.7294
# Epoch 9/250
# 10/10 [==============================] - 7s 667ms/step - loss: 0.5460 - accuracy: 0.7318
# ...

# %% [markdown]
# ### Performing the testing on the test data

# %%
from sklearn.metrics import confusion_matrix
import numpy as np



test_generator = ImageDataGenerator()
test_data_generator = test_datagen.flow_from_directory(
    test_data_path,
    target_size=(img_width, img_height),
    batch_size=32,
    color_mode='grayscale',
    
    shuffle=False)
test_steps_per_epoch = numpy.math.ceil(test_data_generator.samples / test_data_generator.batch_size)

predictions = model.predict_generator(test_data_generator, steps=test_steps_per_epoch)
predictions[predictions<=0.5] = 0
predictions[predictions>0.5] = 1

predicted_classes = (predictions).astype(np.int)

true_classes = test_data_generator.classes
class_labels = list(test_data_generator.class_indices.keys())   

report = metrics.classification_report(true_classes, predicted_classes, target_names=class_labels)
print(report)

cm = confusion_matrix(true_classes, predicted_classes)
total = sum(sum(cm))
acc = (cm[0, 0] + cm[1, 1]) / total
sensitivity = cm[0, 0] / (cm[0, 0] + cm[0, 1])
specificity = cm[1, 1] / (cm[1, 0] + cm[1, 1])

# show the confusion matrix, accuracy, sensitivity, and specificity
print(cm)
print("acc: {:.4f}".format(acc))
print("sensitivity: {:.4f}".format(sensitivity))
print("specificity: {:.4f}".format(specificity))
# Out:
# Found 202 images belonging to 2 classes.
#               precision    recall  f1-score   support
#
#        calls       0.83      0.64      0.73       101
#     no_calls       0.71      0.87      0.78       101
#
#     accuracy                           0.76       202
#    macro avg       0.77      0.76      0.75       202
# weighted avg       0.77      0.76      0.75       202
#
# [[65 36]
#  [13 88]]
# acc: 0.7574
# sensitivity: 0.6436
# specificity: 0.8713

# %% [markdown]
# ### Accuracy around 75.7%
