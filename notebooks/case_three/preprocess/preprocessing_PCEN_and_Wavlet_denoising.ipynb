# %% [markdown]
# <a href="https://colab.research.google.com/github/kunakl07/Backend-of-Active-Learning/blob/pre_spec_al/Case_three/Preprocess/preprocessing_PCEN_and_Wavlet_denoising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Flowchart
#
#
# ![Here is the flowchart of the steps that I hve taken in my notebook](https://drive.google.com/uc?export=view&id=1a8YUCGo4CMkiCC_JugKPt9686BQVZ_bJ)

# %% [markdown]
# # Contents
#
# - [Preprocessing](#Preprocessing-Stage)
#   - [Importing packages](#Importing-the-necessary-packages)
#   - [Standardize](#Standardize-the-tsv-files)
#   - [Extract positive and negative calls from audio using tsv's](#Extract)
#   - [Apply PCEN](#PCEN)
#   - [Apply Wavelet Denoising](#Wavelet-denoising)
#   - [Plot Spectrograms](#Spec-generate)
#   - [Same steps for test data](#test-data)
# - [Training Stage](#Training-Stage)
#    - [Basic CNN model](#Basic-CNN-model)
#    - [VGG16-model](#VGG-16-model)

# %% [markdown]
# #**Preprocessing Stage**

# %% [markdown]
# ###Downloading the PodcastR2,PodcastR3 and Podcast_Test files and extracting them.
# ####Since these files contains the calls of SRKW, only podcastR2 and podcastR3 have been downloaded and used

# %%
# !apt-get -qq install awscli
# !aws --no-sign-request s3 cp s3://acoustic-sandbox/labeled-data/detection/train/OrcasoundLab07052019_PodCastRound2.tar.gz ./ 
# !aws --no-sign-request s3 cp s3://acoustic-sandbox/labeled-data/detection/train/OrcasoundLab09272017_PodCastRound3.tar.gz ./
# !aws --no-sign-request s3 cp s3://acoustic-sandbox/labeled-data/detection/test/OrcasoundLab09272017_Test.tar.gz ./
# !tar -xzf OrcasoundLab09272017_PodCastRound3.tar.gz
# !tar -xzf OrcasoundLab07052019_PodCastRound2.tar.gz
# !tar -xzf OrcasoundLab09272017_Test.tar.gz
# !pip -q install ketos==2.0.0b4
# !pip -q install pysoundfile
# !pip install pydub
# Out:
# Selecting previously unselected package sgml-base.
# (Reading database ... 144328 files and directories currently installed.)
# Preparing to unpack .../00-sgml-base_1.29_all.deb ...
# Unpacking sgml-base (1.29) ...
# Selecting previously unselected package python3-yaml.
# Preparing to unpack .../01-python3-yaml_3.12-1build2_amd64.deb ...
# Unpacking python3-yaml (3.12-1build2) ...
# Selecting previously unselected package python3-six.
# Preparing to unpack .../02-python3-six_1.11.0-2_all.deb ...
# Unpacking python3-six (1.11.0-2) ...
# Selecting previously unselected package python3-dateutil.
# Preparing to unpack .../03-python3-dateutil_2.6.1-1_all.deb ...
# Unpacking python3-dateutil (2.6.1-1) ...
# Selecting previously unselected package xml-core.
# Preparing to unpack .../04-xml-core_0.18_all.deb ...
# Unpacking xml-core (0.18) ...
# Selecting previously unselected package docutils-common.
# Preparing to unpack .../05-docutils-common_0.14+dfsg-3_all.deb ...
# Unpacking docutils-common (0.14+dfsg-3) ...
# Selecting previously unselected package python3-roman.
# Preparing to unpack .../06-python3-roman_2.0.0-3_all.deb ...
# Unpacking python3-roman (2.0.0-3) ...
# Selecting previously unselected package python3-docutils.
# Preparing to unpack .../07-python3-docutils_0.14+dfsg-3_all.deb ...
# Unpacking python3-docutils (0.14+dfsg-3) ...
# Selecting previously unselected package python3-jmespath.
# Preparing to unpack .../08-python3-jmespath_0.9.3-1ubuntu1_all.deb ...
# Unpacking python3-jmespath (0.9.3-1ubuntu1) ...
# Selecting previously unselected package python3-certifi.
# Preparing to unpack .../09-python3-certifi_2018.1.18-2_all.deb ...
# Unpacking python3-certifi (2018.1.18-2) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../10-python3-pkg-resources_39.0.1-2_all.deb ...
# Unpacking python3-pkg-resources (39.0.1-2) ...
# Selecting previously unselected package python3-chardet.
# Preparing to unpack .../11-python3-chardet_3.0.4-1_all.deb ...
# Unpacking python3-chardet (3.0.4-1) ...
# Selecting previously unselected package python3-idna.
# Preparing to unpack .../12-python3-idna_2.6-1_all.deb ...
# Unpacking python3-idna (2.6-1) ...
# Selecting previously unselected package python3-urllib3.
# Preparing to unpack .../13-python3-urllib3_1.22-1ubuntu0.18.04.1_all.deb ...
# Unpacking python3-urllib3 (1.22-1ubuntu0.18.04.1) ...
# Selecting previously unselected package python3-requests.
# Preparing to unpack .../14-python3-requests_2.18.4-2ubuntu0.1_all.deb ...
# Unpacking python3-requests (2.18.4-2ubuntu0.1) ...
# Selecting previously unselected package python3-botocore.
# Preparing to unpack .../15-python3-botocore_1.8.48+repack-1_all.deb ...
# Unpacking python3-botocore (1.8.48+repack-1) ...
# Selecting previously unselected package python3-colorama.
# Preparing to unpack .../16-python3-colorama_0.3.7-1_all.deb ...
# Unpacking python3-colorama (0.3.7-1) ...
# Selecting previously unselected package python3-pyasn1.
# Preparing to unpack .../17-python3-pyasn1_0.4.2-3_all.deb ...
# Unpacking python3-pyasn1 (0.4.2-3) ...
# Selecting previously unselected package python3-rsa.
# Preparing to unpack .../18-python3-rsa_3.4.2-1_all.deb ...
# Unpacking python3-rsa (3.4.2-1) ...
# Selecting previously unselected package python3-s3transfer.
# Preparing to unpack .../19-python3-s3transfer_0.1.13-1_all.deb ...
# Unpacking python3-s3transfer (0.1.13-1) ...
# Selecting previously unselected package awscli.
# Preparing to unpack .../20-awscli_1.14.44-1ubuntu1_all.deb ...
# Unpacking awscli (1.14.44-1ubuntu1) ...
# Selecting previously unselected package python3-olefile.
# Preparing to unpack .../21-python3-olefile_0.45.1-1_all.deb ...
# Unpacking python3-olefile (0.45.1-1) ...
# Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../22-python3-pil_5.1.0-1ubuntu0.2_amd64.deb ...
# Unpacking python3-pil:amd64 (5.1.0-1ubuntu0.2) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../23-python3-pygments_2.2.0+dfsg-1_all.deb ...
# Unpacking python3-pygments (2.2.0+dfsg-1) ...
# Setting up python3-yaml (3.12-1build2) ...
# Setting up python3-roman (2.0.0-3) ...
# Setting up python3-pil:amd64 (5.1.0-1ubuntu0.2) ...
# Setting up python3-olefile (0.45.1-1) ...
# Setting up python3-idna (2.6-1) ...
# Setting up python3-six (1.11.0-2) ...
# Setting up python3-colorama (0.3.7-1) ...
# Setting up python3-certifi (2018.1.18-2) ...
# Setting up sgml-base (1.29) ...
# Setting up python3-pkg-resources (39.0.1-2) ...
# Setting up python3-pyasn1 (0.4.2-3) ...
# Setting up python3-chardet (3.0.4-1) ...
# Setting up python3-urllib3 (1.22-1ubuntu0.18.04.1) ...
# Setting up python3-jmespath (0.9.3-1ubuntu1) ...
# Setting up xml-core (0.18) ...
# Setting up python3-dateutil (2.6.1-1) ...
# Setting up python3-pygments (2.2.0+dfsg-1) ...
# Setting up python3-rsa (3.4.2-1) ...
# Setting up python3-requests (2.18.4-2ubuntu0.1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for shared-mime-info (1.9-2) ...
# Processing triggers for sgml-base (1.29) ...
# Setting up docutils-common (0.14+dfsg-3) ...
# Processing triggers for sgml-base (1.29) ...
# Setting up python3-docutils (0.14+dfsg-3) ...
# update-alternatives: using /usr/share/docutils/scripts/python3/rst-buildhtml to provide /usr/bin/rst-buildhtml (rst-buildhtml) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2html to provide /usr/bin/rst2html (rst2html) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2html4 to provide /usr/bin/rst2html4 (rst2html4) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2html5 to provide /usr/bin/rst2html5 (rst2html5) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2latex to provide /usr/bin/rst2latex (rst2latex) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2man to provide /usr/bin/rst2man (rst2man) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2odt to provide /usr/bin/rst2odt (rst2odt) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2odt_prepstyles to provide /usr/bin/rst2odt_prepstyles (rst2odt_prepstyles) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2pseudoxml to provide /usr/bin/rst2pseudoxml (rst2pseudoxml) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2s5 to provide /usr/bin/rst2s5 (rst2s5) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2xetex to provide /usr/bin/rst2xetex (rst2xetex) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rst2xml to provide /usr/bin/rst2xml (rst2xml) in auto mode
# update-alternatives: using /usr/share/docutils/scripts/python3/rstpep2html to provide /usr/bin/rstpep2html (rstpep2html) in auto mode
# Setting up python3-botocore (1.8.48+repack-1) ...
# Setting up python3-s3transfer (0.1.13-1) ...
# Setting up awscli (1.14.44-1ubuntu1) ...
# download: s3://acoustic-sandbox/labeled-data/detection/train/OrcasoundLab07052019_PodCastRound2.tar.gz to ./OrcasoundLab07052019_PodCastRound2.tar.gz
# download: s3://acoustic-sandbox/labeled-data/detection/train/OrcasoundLab09272017_PodCastRound3.tar.gz to ./OrcasoundLab09272017_PodCastRound3.tar.gz
# download: s3://acoustic-sandbox/labeled-data/detection/test/OrcasoundLab09272017_Test.tar.gz to ./OrcasoundLab09272017_Test.tar.gz
#      |████████████████████████████████| 122kB 2.7MB/s
#      |████████████████████████████████| 421.8MB 25kB/s
#      |████████████████████████████████| 204kB 47.3MB/s
#      |████████████████████████████████| 450kB 31.0MB/s
#      |████████████████████████████████| 3.9MB 37.2MB/s
#   Building wheel for ketos (setup.py) ... done
#   Building wheel for datetime-glob (setup.py) ... done
#   Building wheel for gast (setup.py) ... done
#   Building wheel for lexery (setup.py) ... done
# ERROR: tensorflow-probability 0.10.0 has requirement gast>=0.3.2, but you'll have gast 0.2.2 which is incompatible.
# Collecting pydub
#   Downloading https://files.pythonhosted.org/packages/7b/d1/fbfa79371a8cd9bb15c2e3c480d7e6e340ed5cc55005174e16f48418333a/pydub-0.24.1-py2.py3-none-any.whl
# Installing collected packages: pydub
# Successfully installed pydub-0.24.1

# %% [markdown]
# ##Preprocessing on positive train dataset

# %% [markdown]
# ###Importing the necessary packages

# %%
import pandas as pd
from ketos.data_handling import selection_table as sl
from ketos.data_handling.parsing import load_audio_representation
import numpy as np
from os import listdir
from os.path import isfile, join
from scipy import signal
import soundfile as sf
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from pydub import AudioSegment
import librosa
import os
import soundfile as sf
from skimage.restoration import (denoise_wavelet, estimate_sigma)

# %%
#Generate mean and annot-train
def duration_mean(filename):
    annot_train = pd.read_csv(filename, sep='\t')
    mean=annot_train['duration_s'].mean()
    return annot_train,mean

# %%
#Function to add the end time
def add_end(filename):
    filename["end"]=filename["start"]+filename["duration_s"]

# %%
#Function to find extract filename and start time
def fname_stime(filename):
    file_name=filename.iloc[:,0].values
    start_time=filename.iloc[:,1].values
    return file_name,start_time

# %%
#Function to extract audio from the .wav files to generate complete positive and negative calls
def extract_audio(label,filename,path,position):
    file_name=filename.iloc[:,0].values
    start_time=filename.iloc[:,position].values
    i=0
    o=0
    for x in file_name:
  
        AUDIO_FILE=x
        sound = AudioSegment.from_file(AUDIO_FILE)
        p=start_time[i]
        p=p*1000
        print(p)
        i=i+1
        o=p+2000
        call=sound[p:o]
        call.export(path+label+ "MMMcalls{0}.wav".format(i),format="wav")

# %%
def apply_per_channel_energy_norm(data, sampling_rate):
    '''Compute Per-Channel Energy Normalization (PCEN)'''
    S = librosa.feature.melspectrogram(
        data, sr=sampling_rate, power=1)  # Compute mel-scaled spectrogram
    # Convert an amplitude spectrogram to dB-scaled spectrogram
    log_S = librosa.amplitude_to_db(S, ref=np.max)
    pcen_S = librosa.core.pcen(S)
    return pcen_S

# %%
def wavelet_denoising(data):
    '''
    Wavelet Denoising using scikit-image
    NOTE: Wavelet denoising is an effective method for SNR improvement in environments with
              wide range of noise types competing for the same subspace.
    '''
    sigma_est = estimate_sigma(data, multichannel=False, average_sigmas=True)
    im_bayes = denoise_wavelet(data, multichannel=False, convert2ycbcr=False, method='BayesShrink',
                               mode='soft')
    im_visushrink = denoise_wavelet(data, multichannel=False, convert2ycbcr=False, method='VisuShrink',
                                    mode='soft')

    # VisuShrink is designed to eliminate noise with high probability, but this
    # results in a visually over-smooth appearance. Here, we specify a reduction
    # in the threshold by factors of 2 and 4.
    im_visushrink2 = denoise_wavelet(data, multichannel=False, convert2ycbcr=False, method='VisuShrink',
                                     mode='soft', sigma=sigma_est / 2)
    im_visushrink4 = denoise_wavelet(data, multichannel=False, convert2ycbcr=False, method='VisuShrink',
                                     mode='soft', sigma=sigma_est / 4)
    return im_bayes

# %%
def plot_and_save(denoised_data, f_name):

    fig, ax = plt.subplots()

    i = 0
    # Add this line to show plots else ignore warnings
    # plt.ion()

    ax.imshow(denoised_data)
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    fig.set_size_inches(10, 10)
    fig.savefig(
        f"{f_name[:-4]}" + "_{:04d}.png".format(i),
        dpi=80,
        bbox_inches="tight",
        quality=95,
        pad_inches=0.0)

    fig.canvas.draw()
    fig.canvas.flush_events()
    i += 1
    plt.close(fig)

# %%
def final_plot(base_path,plot_path,folder_path):

    basePath = base_path
    plotPath = join(basePath,plot_path)
    folderpath = join(basePath, folder_path)
    onlyfiles = [f for f in listdir(folderpath) if isfile(join(join(folderpath, f)))]

    for idx,file in enumerate(onlyfiles):
        #data, samplerate = sf.read(join(folderpath, file))
   
        data, sr = librosa.core.load(
                    os.path.join(folderpath, file), res_type='kaiser_best')
        #print(data)
        #print(sf)
        f_name = os.path.basename(file)
        pcen_S = apply_per_channel_energy_norm(data, sr)

        denoised_data = wavelet_denoising(pcen_S)
        plot_and_save(denoised_data, f_name)

# %%
# !pwd
# Out:
# /content/Round3_OS_09_27_2017/wav

# %% [markdown]
# ####The tsv files contains the parameters like start_time,duration_s,etc, but since these are not in the format Ketos accepts,we need to perform some changes in labels and therefore these files have been uploaded from the local machine

# %%
annot_train2,mean2=duration_mean('/content/podcast2.tsv')
annot_train3,mean3 = duration_mean('/content/podcast3.tsv')
annot_test,mean_test = duration_mean('/content/v10_test.tsv')

print(mean2)
annot_train2.head()
# Out:
# 2.1110548004254963
#           wav_filename      start  ...  data_source_id  label
# 0  1562337136_0004.wav  49.765625  ...      1562337136  SRKWs
# 1  1562337136_0004.wav  41.046007  ...      1562337136  SRKWs
# 2  1562337136_0004.wav  37.345486  ...      1562337136  SRKWs
# 3  1562337136_0004.wav  42.917535  ...      1562337136  SRKWs
# 4  1562337136_0004.wav  45.980035  ...      1562337136  SRKWs
#
# [5 rows x 8 columns]

# %% [markdown]
# ####Here is how the .tsv files and their labels look like when they are in format that could be accepted by ketos

# %%
add_end(annot_train2)
add_end(annot_train3)
add_end(annot_test)
annot_train2.head()
# Out:
#           wav_filename      start  duration_s  ... data_source_id  label        end
# 0  1562337136_0004.wav  49.765625    2.450000  ...     1562337136  SRKWs  52.215625
# 1  1562337136_0004.wav  41.046007    1.658854  ...     1562337136  SRKWs  42.704861
# 2  1562337136_0004.wav  37.345486    1.743924  ...     1562337136  SRKWs  39.089410
# 3  1562337136_0004.wav  42.917535    2.594618  ...     1562337136  SRKWs  45.512153
# 4  1562337136_0004.wav  45.980035    2.041667  ...     1562337136  SRKWs  48.021701
#
# [5 rows x 9 columns]

# %% [markdown]
# ###Standardizing the tsv files

# %%
map_to_ketos_annot_std ={'wav_filename': 'filename'} 
std_annot_train2 = sl.standardize(table=annot_train2, signal_labels=["SRKWs"], mapper=map_to_ketos_annot_std, trim_table=True)
std_annot_train3 = sl.standardize(table=annot_train3, signal_labels=["SRKWs"], mapper=map_to_ketos_annot_std, trim_table=True)

std_annot_test = sl.standardize(table=annot_test, signal_labels=["SRKWs"], mapper=map_to_ketos_annot_std, trim_table=True)

# %% [markdown]
# ###Here we could see how each these tsv files look like after standardizing

# %%
std_annot_train2.head()
# Out:
#                                   start  label        end
# filename            annot_id
# 1562337136_0004.wav 0         49.765625      1  52.215625
#                     1         41.046007      1  42.704861
#                     2         37.345486      1  39.089410
#                     3         42.917535      1  45.512153
#                     4         45.980035      1  48.021701

# %%
std_annot_train3.head()
# Out:
#                                               start  label        end
# filename                        annot_id
# OS_9_27_2017_08_14_00__0002.wav 0          6.110451      1   7.856295
# OS_9_27_2017_08_14_00__0004.wav 0         12.717882      1  15.167882
#                                 1         29.825347      1  31.637326
#                                 2         43.504514      1  45.103819
#                                 3         48.404514      1  50.344097

# %%
std_annot_test.head()
# Out:
#                                               start  label        end
# filename                        annot_id
# OS_9_27_2017_08_14_00__0001.wav 0         11.643564      1  14.093564
#                                 1         15.594059      1  17.759901
#                                 2         53.900000      1  56.350000
#                                 3         59.781486      1  61.250000
# OS_9_27_2017_08_19_00__0002.wav 0          6.592882      1   7.826389

# %% [markdown]
# ###Saving these standardized tsv files

# %%
std_annot_train2.to_csv('standardized_train2.tsv', mode='a', sep='\t',header=False)
std_annot_train3.to_csv('standardized_train3.tsv', mode='a', sep='\t',header=False)
std_annot_test.to_csv('standardized_test.tsv', mode='a', sep='\t',header=False)

# %%
# %cd /content/
# Out:
# /content

# %% [markdown]
# ###Saving these standardized tsv files

# %%
annot_id2 = pd.read_csv('/content/standardized_train2.tsv', sep='\t')
annot_id3 = pd.read_csv('/content/standardized_train3.tsv', sep='\t')
annot_idtest = pd.read_csv('/content/standardized_test.tsv', sep='\t')
#annot_val=pd.read_csv('/content/standardized_val.tsv', sep='\t')

# %% [markdown]
# ####Extracting the .wav file names and start time from these .tsv files which would be used by Pydub to extract small segemets of sounds(one containing the calls and the other not)

# %%
filename,start_time=fname_stime(annot_train2)
print(filename[0])
print(start_time[0])
annot_train2.head()
# Out:
# 1562337136_0004.wav
# 49.765625
#           wav_filename      start  duration_s  ... data_source_id  label        end
# 0  1562337136_0004.wav  49.765625    2.450000  ...     1562337136  SRKWs  52.215625
# 1  1562337136_0004.wav  41.046007    1.658854  ...     1562337136  SRKWs  42.704861
# 2  1562337136_0004.wav  37.345486    1.743924  ...     1562337136  SRKWs  39.089410
# 3  1562337136_0004.wav  42.917535    2.594618  ...     1562337136  SRKWs  45.512153
# 4  1562337136_0004.wav  45.980035    2.041667  ...     1562337136  SRKWs  48.021701
#
# [5 rows x 9 columns]

# %% [markdown]
# ####We could verify the start time and the file duration matches to the same column as above

# %% [markdown]
# ####We would change to the directory from where we want to extract calls using pydub

# %%
# !pwd
# Out:
# /content

# %%
# %cd /content/Round2_OS_07_05/wav
# Out:
# /content/Round2_OS_07_05/wav

# %%
# !mkdir pod_calls

# %%
extract_audio('round2_calls',annot_train2,"/content/Round2_OS_07_05/wav/pod_calls/",1)

# %% [markdown]
# ####Extracting the start time plus two second sound which we know by taking the mean of the duration

# %%
# %cd /content/Round3_OS_09_27_2017/wav
# Out:
# /content/Round3_OS_09_27_2017/wav

# %% [markdown]
# ####Similarly we would extract the calls for podcast3

# %%
extract_audio('round3_calls',annot_train3,"/content/Round2_OS_07_05/wav/pod_calls/",1)

# %% [markdown]
# ####Verify the calls that we extracted are of annotated three itself

# %%
annot_train3.head()
# Out:
#                       wav_filename      start  ...  label        end
# 0  OS_9_27_2017_08_14_00__0002.wav   6.110451  ...  SRKWs   7.856295
# 1  OS_9_27_2017_08_14_00__0004.wav  12.717882  ...  SRKWs  15.167882
# 2  OS_9_27_2017_08_14_00__0004.wav  29.825347  ...  SRKWs  31.637326
# 3  OS_9_27_2017_08_14_00__0004.wav  43.504514  ...  SRKWs  45.103819
# 4  OS_9_27_2017_08_14_00__0004.wav  48.404514  ...  SRKWs  50.344097
#
# [5 rows x 9 columns]

# %%
# %cd /content/Round2_OS_07_05
# Out:
# /content/Round2_OS_07_05

# %% [markdown]
# ###In the Round2 folder we are going to create two folders train and test respectively and in each of the folders we are going to create calls and nocalls folders respectively

# %%
# !mkdir train
# !mkdir test
# %cd train
# !mkdir calls
# !mkdir nocalls
# %cd /content/Round2_OS_07_05/test
# Out:
# /content/Round2_OS_07_05/train
# /content/Round2_OS_07_05/test

# %%
# !pwd
# !mkdir calls
# !mkdir nocalls
# Out:
# /content/Round2_OS_07_05/test

# %% [markdown]
# ###Now we would plot the graphs i.e the spectrograms without x and y labels into calls folder

# %%
final_plot('/content/Round2_OS_07_05/','train/calls','wav/pod_calls/')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# ...
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.

# %% [markdown]
# ##Generation of spectrograms from the background sounds

# %% [markdown]
# ####Since we have generated the positive calls, its time to generate the negative ones.

# %% [markdown]
# ####The above table shows the time area for the podcast-2 and podcast-3 which does not contain the calls timeframe
# ####The table displays the start time and the end time that does not contain the calls

# %%
positives_train2 = sl.select(annotations=std_annot_train2, length=2.0)
file_durations_train2 = sl.file_duration_table('/content/Round2_OS_07_05/wav')
negatives_train2=sl.create_rndm_backgr_selections(annotations=std_annot_train2, files=file_durations_train2, length=2.0, num=len(positives_train2), trim_table=True)
negatives_train2.head()
# Out:
#                                start        end  label
# filename            sel_id
# 1562337136_0004.wav 0       2.298165   4.298165      0
#                     1       6.010853   8.010853      0
#                     2       6.188857   8.188857      0
#                     3       7.792858   9.792858      0
#                     4       9.846330  11.846330      0

# %% [markdown]
# ####Extracting the area by looking at time where there are no occurences of calls in tsv file

# %%
positives_train3 = sl.select(annotations=std_annot_train3, length=2.0)
file_durations_train33 = sl.file_duration_table('/content/Round3_OS_09_27_2017/wav')
negatives_train33=sl.create_rndm_backgr_selections(annotations=std_annot_train3, files=file_durations_train33, length=2.0, num=len(positives_train3), trim_table=True)
negatives_train33.head()
# Out:
#                                             start        end  label
# filename                        sel_id
# OS_9_27_2017_08_03_00__0002.wav 0        2.158776   4.158776      0
#                                 1       14.006486  16.006486      0
#                                 2       14.741979  16.741979      0
#                                 3       20.980461  22.980461      0
#                                 4       27.223733  29.223733      0

# %% [markdown]
# ###Then the steps for generating audio is same as we did above for the positive calls

# %%
# !pwd
# Out:
# /content/Round2_OS_07_05/test

# %%
# %cd '/content/Round2_OS_07_05/wav'
# Out:
# /content/Round2_OS_07_05/wav

# %%
# !mkdir neg_pod_calls

# %%
# %cd /content
# Out:
# /content

# %%
negatives_train2.to_csv('negative2.tsv', mode='a', sep='\t',header=False)
negatives_train33.to_csv('negative3.tsv', mode='a', sep='\t',header=False)

# %%
negatives_train2save=pd.read_csv('/content/negative2.tsv',sep='\t')
negatives_train33save=pd.read_csv('/content/negative3.tsv',sep='\t')

# %%
negatives_train2save.head()
# Out:
#    1562337136_0004.wav  0  2.298164947921821  4.298164947921821  0.1
# 0  1562337136_0004.wav  1           6.010853           8.010853    0
# 1  1562337136_0004.wav  2           6.188857           8.188857    0
# 2  1562337136_0004.wav  3           7.792858           9.792858    0
# 3  1562337136_0004.wav  4           9.846330          11.846330    0
# 4  1562337136_0004.wav  5          15.501313          17.501313    0

# %%
# %cd /content/Round2_OS_07_05/wav
# Out:
# /content/Round2_OS_07_05/wav

# %%
extract_audio('r2negcalls_calls',negatives_train2save,"/content/Round2_OS_07_05/wav/neg_pod_calls/",2)

# %%
# %cd '/content/Round3_OS_09_27_2017/wav'
# Out:
# /content/Round3_OS_09_27_2017/wav

# %%
extract_audio('r3neg_calls',negatives_train33save,"/content/Round2_OS_07_05/wav/neg_pod_calls/",2)

# %%
negatives_train33save.head()
# Out:
#    OS_9_27_2017_08_03_00__0002.wav  0  ...  4.158776062680616  0.1
# 0  OS_9_27_2017_08_03_00__0002.wav  1  ...          16.006486    0
# 1  OS_9_27_2017_08_03_00__0002.wav  2  ...          16.741979    0
# 2  OS_9_27_2017_08_03_00__0002.wav  3  ...          22.980461    0
# 3  OS_9_27_2017_08_03_00__0002.wav  4  ...          29.223733    0
# 4  OS_9_27_2017_08_03_00__0003.wav  0  ...           7.383801    0
#
# [5 rows x 5 columns]

# %%
# %cd '/content/Round2_OS_07_05/train/train/nocalls'
# Out:
# /content/Round2_OS_07_05/train/train/nocalls

# %%
final_plot('/content/Round2_OS_07_05/','train/nocalls','wav/neg_pod_calls')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# ...
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.

# %% [markdown]
# ###Now we have saved the images(spectrograms) of the negtive calls

# %% [markdown]
# ##We would perform similar steps with test data as well where in :
#
# *   Extract area responsible for the call from the Orcasound_test tsv file
# *   Standardize that tsv file
# *   Generate 2 second calls that contains the audio data
# *   Generate background sound from tsv of 2 seconds
# *   Generate spectrograms from these sounds
#
#
#
# ---

# %%
# %cd /content/Round2_OS_07_05/wav
# !mkdir pod_calls_test
# !mkdir pod_calls_neg_test
# Out:
# /content/Round2_OS_07_05/wav

# %%
# %cd '/content/OrcasoundLab09272017_Test/wav'
# Out:
# /content/OrcasoundLab09272017_Test/wav

# %%
annot_test.head()
# Out:
#                       wav_filename      start  ...  label        end
# 0  OS_9_27_2017_08_14_00__0001.wav  11.643564  ...  SRKWs  14.093564
# 1  OS_9_27_2017_08_14_00__0001.wav  15.594059  ...  SRKWs  17.759901
# 2  OS_9_27_2017_08_14_00__0001.wav  53.900000  ...  SRKWs  56.350000
# 3  OS_9_27_2017_08_14_00__0001.wav  59.781486  ...  SRKWs  61.250000
# 4  OS_9_27_2017_08_19_00__0002.wav   6.592882  ...  SRKWs   7.826389
#
# [5 rows x 9 columns]

# %%
# %cd /content/OrcasoundLab09272017_Test/wav
# Out:
# /content/OrcasoundLab09272017_Test/wav

# %%
extract_audio('test_calls',annot_test,"/content/Round2_OS_07_05/wav/pod_test",1)

# %%
# %cd /content/Round2_OS_07_05/Train_phase/test/calls
# Out:
# /content/Round2_OS_07_05/Train_phase/test/calls

# %%
final_plot('/content/Round2_OS_07_05/','Train_phase/test/calls/','wav/pod_calls_test')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# ...
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.

# %%
positives_test = sl.select(annotations=std_annot_test, length=2.0)
file_durations_test = sl.file_duration_table('/content/OrcasoundLab09272017_Test/wav')
negatives_test=sl.create_rndm_backgr_selections(annotations=std_annot_test, files=file_durations_test, length=2.0, num=len(positives_test), trim_table=True)
negatives_test.to_csv('negg.tsv', mode='a', sep='\t',header=False)

# %%
# %cd '/content/'
negatives_test.to_csv('negg.tsv', mode='a', sep='\t',header=False)
# Out:
# /content

# %%
# %cd '/content/OrcasoundLab09272017_Test/wav'
# Out:
# /content/OrcasoundLab09272017_Test/wav

# %%
# %cd '/content/OrcasoundLab09272017_Test/wav'
# Out:
# /content/OrcasoundLab09272017_Test/wav

# %%
neg=pd.read_csv('/content/negg.tsv',sep='\t')
extract_audio('r3neg_calls_test',neg,"/content/Round2_OS_07_05/wav/neg_pod_calls_test/",2)

# %%
neg.head()
# Out:
#    OS_9_27_2017_08_14_00__0001.wav  0  ...  8.927192787596848  0.1
# 0  OS_9_27_2017_08_14_00__0001.wav  1  ...          24.621372    0
# 1  OS_9_27_2017_08_19_00__0002.wav  0  ...          29.183743    0
# 2  OS_9_27_2017_08_19_00__0002.wav  1  ...          47.684807    0
# 3  OS_9_27_2017_08_25_00__0003.wav  0  ...           2.781363    0
# 4  OS_9_27_2017_08_25_00__0003.wav  1  ...          11.588556    0
#
# [5 rows x 5 columns]

# %%
# %cd /content/Round2_OS_07_05/Train_phase/test/nocalls
# Out:
# /content/Round2_OS_07_05/Train_phase/test/nocalls

# %%
final_plot('/content/Round2_OS_07_05/','test/nocalls','wav/neg_pod_calls_test')
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# ...
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:17: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: DeprecationWarning: As of scikit-image 0.16, automated rescaling of sigma to match any internal rescaling of the image is performed. Setting rescale_sigma to False, will disable this new behaviour. To avoid this warning the user should explicitly set rescale_sigma to True or False.

# %% [markdown]
# #Saving and training

# %%
# !zip -r /content/pcen_and_wavelet_trainsave_two_sec_save.zip /content/Round2_OS_07_05/Train_phase
# Out:
#   adding: content/Round2_OS_07_05/Train_phase/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/.ipynb_checkpoints/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/test/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls98_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls65_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls63_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls16_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls80_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls81_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls28_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls84_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls1_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls41_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls38_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls46_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls21_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls27_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls78_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls18_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls99_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls7_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls3_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls5_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls40_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls47_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls37_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls74_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls79_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls20_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls66_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls29_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls32_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls92_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls39_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls64_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls49_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls36_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls52_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls23_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls90_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls48_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls70_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls15_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls24_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls44_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls82_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls86_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls2_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls83_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls51_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls35_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls71_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls33_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls19_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls94_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls75_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls42_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls96_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls58_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls6_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls59_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls93_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls34_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls100_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls22_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls4_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls13_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls69_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls72_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls11_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls45_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls43_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls67_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls95_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls31_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls85_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls62_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls14_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls55_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls26_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls25_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls76_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls53_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls91_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls88_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls54_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls61_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls87_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls97_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls17_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls9_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls57_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls8_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls89_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls68_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls12_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls56_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls10_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls50_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls77_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls30_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls60_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls73_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/.ipynb_checkpoints/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls18_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls24_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls59_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls98_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls37_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls39_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls3_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls80_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls78_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls47_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls86_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls46_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls49_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls28_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls11_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls48_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls8_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls6_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls14_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls2_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls64_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls15_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls53_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls51_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls7_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls91_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls10_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls75_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls1_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls16_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls100_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls36_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls63_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls34_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls77_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls42_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls67_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls25_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls55_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls82_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls79_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls57_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls61_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls76_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls58_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls32_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls13_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls87_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls45_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls97_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls69_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls22_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls60_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls50_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls31_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls52_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls12_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls41_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls73_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls89_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls71_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls21_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls27_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls90_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls33_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls20_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls9_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls35_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls94_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls62_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls66_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls68_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls44_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls65_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls95_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls19_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls5_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls26_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls101_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls83_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls74_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls17_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls43_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls88_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls81_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls96_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls23_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls93_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls38_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls92_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls30_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls84_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls70_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls56_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls85_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls99_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls4_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls29_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls54_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls40_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls72_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls198_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls58_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls147_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls205_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls21_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls16_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls172_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls254_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls280_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls206_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls319_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls76_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls381_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls12_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls373_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls77_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls60_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls72_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls285_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls355_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls137_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls417_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls292_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls419_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls79_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls174_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls143_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls99_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls401_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls20_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls266_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls55_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls261_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls350_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls234_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls221_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls59_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls239_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls327_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls70_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls165_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls277_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls229_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls41_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls152_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls14_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls104_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls182_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls301_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls310_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls145_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls88_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls64_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls125_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls74_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls140_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls52_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls158_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls10_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls85_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls179_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls390_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls260_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls1_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls271_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls136_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls349_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls118_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls188_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls103_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls16_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls294_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls5_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls362_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls252_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls66_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls68_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls275_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls75_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls365_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls157_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls133_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls139_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls308_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls329_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls335_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls42_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls75_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls161_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls97_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls402_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls99_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls209_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls28_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls116_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls47_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls35_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls11_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls100_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls353_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls115_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls61_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls167_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls298_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls42_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls145_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls92_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls227_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls356_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls363_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls391_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls382_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls8_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls361_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls315_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls332_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls200_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls242_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls217_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls337_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls319_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls331_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls316_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls24_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls169_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls113_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls309_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls222_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls304_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls86_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls9_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls146_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls338_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls84_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls110_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls101_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls71_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls48_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls204_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls11_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls85_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls98_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls113_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls166_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls32_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls60_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls251_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls219_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls126_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls126_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls159_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls309_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls188_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls10_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls384_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls168_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls78_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls259_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls39_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls233_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls334_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls90_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls290_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls345_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls287_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls346_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls176_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls252_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls87_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls367_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls141_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls234_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls129_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls195_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls57_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls13_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls342_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls240_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls245_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls375_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls283_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls413_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls181_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls19_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls103_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls30_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls302_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls412_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls136_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls268_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls160_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls83_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls255_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls32_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls279_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls63_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls261_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls408_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls69_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls264_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls289_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls301_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls253_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls275_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls65_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls343_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls235_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls155_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls2_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls170_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls31_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls296_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls344_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls22_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls177_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls231_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls102_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls23_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls76_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls111_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls94_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls263_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls380_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls96_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls246_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls125_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls318_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls299_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls3_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls354_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls315_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls340_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls165_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls281_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls336_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls244_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls236_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls81_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls153_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls210_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls2_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls293_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r3neg_callsMMMcalls385_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/nocalls/r2negcalls_callsMMMcalls222_0000.png (deflated 7%)
# ...
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls347_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls255_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls124_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls427_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls316_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls57_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls320_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls190_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls128_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls94_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls27_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls3_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls144_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls23_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls256_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls33_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls55_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls38_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls328_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls162_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls287_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls403_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls318_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls334_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls268_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls77_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls282_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls140_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls277_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls111_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls198_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls291_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls196_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls61_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls240_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls243_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls189_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls58_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls117_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls235_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls284_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls200_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls28_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls309_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls264_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls229_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls87_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls260_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls139_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls336_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls300_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls56_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls160_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls194_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls66_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls346_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls89_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls8_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls74_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls127_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls123_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls59_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls299_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls261_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls30_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls224_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls249_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls152_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls212_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls105_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls337_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls14_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls196_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls211_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls250_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls303_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls64_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls364_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls129_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls238_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls63_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls111_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls407_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls56_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls128_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls344_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls383_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls342_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls281_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls93_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls290_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls237_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls103_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls3_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls98_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls105_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls314_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls197_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls429_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls350_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls331_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls78_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls414_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls120_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls307_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls357_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls151_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls197_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls43_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls237_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls218_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls113_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls104_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls375_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls25_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls81_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls234_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls191_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls293_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls71_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls391_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls326_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls165_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls312_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls340_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls23_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls411_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls278_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls298_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls63_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls97_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls405_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls401_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls202_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls83_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls177_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls6_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls49_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls16_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls124_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls173_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls178_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls38_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls162_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls100_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls115_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls109_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls15_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round2_callsMMMcalls243_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls73_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls288_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/train/calls/round3_callsMMMcalls374_0000.png (deflated 8%)

# %%
# !zip -r /content/pcen_and_wavelet_test_two_sec_save.zip /content/Round2_OS_07_05/Train_phase/test
# Out:
#   adding: content/Round2_OS_07_05/Train_phase/test/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls98_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls65_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls63_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls16_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls80_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls81_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls28_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls84_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls1_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls41_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls38_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls46_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls21_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls27_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls78_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls18_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls99_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls7_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls3_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls5_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls40_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls47_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls37_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls74_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls79_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls20_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls66_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls29_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls32_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls92_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls39_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls64_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls49_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls36_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls52_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls23_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls90_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls48_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls70_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls15_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls24_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls44_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls82_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls86_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls2_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls83_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls51_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls35_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls71_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls33_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls19_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls94_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls75_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls42_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls96_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls58_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls6_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls59_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls93_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls34_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls100_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls22_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls4_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls13_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls69_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls72_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls11_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls45_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls43_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls67_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls95_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls31_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls85_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls62_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls14_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls55_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls26_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls25_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls76_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls53_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls91_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls88_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls54_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls61_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls87_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls97_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls17_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls9_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls57_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls8_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls89_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls68_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls12_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls56_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls10_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls50_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls77_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls30_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls60_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/nocalls/r3neg_calls_testMMMcalls73_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/.ipynb_checkpoints/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/ (stored 0%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls18_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls24_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls59_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls98_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls37_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls39_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls3_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls80_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls78_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls47_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls86_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls46_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls49_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls28_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls11_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls48_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls8_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls6_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls14_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls2_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls64_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls15_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls53_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls51_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls7_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls91_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls10_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls75_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls1_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls16_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls100_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls36_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls63_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls34_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls77_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls42_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls67_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls25_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls55_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls82_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls79_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls57_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls61_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls76_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls58_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls32_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls13_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls87_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls45_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls97_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls69_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls22_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls60_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls50_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls31_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls52_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls12_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls41_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls73_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls89_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls71_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls21_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls27_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls90_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls33_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls20_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls9_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls35_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls94_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls62_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls66_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls68_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls44_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls65_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls95_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls19_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls5_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls26_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls101_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls83_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls74_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls17_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls43_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls88_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls81_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls96_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls23_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls93_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls38_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls92_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls30_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls84_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls70_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls56_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls85_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls99_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls4_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls29_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls54_0000.png (deflated 7%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls40_0000.png (deflated 8%)
#   adding: content/Round2_OS_07_05/Train_phase/test/calls/test_callsMMMcalls72_0000.png (deflated 7%)
